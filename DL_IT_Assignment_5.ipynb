# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,\
	Embedding, Lambda
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import re

# %%
data = """We are about to study the idea of a computational process.
Computational processes are abstract beings that inhabit computers.
As they evolve, processes manipulate other abstract things called data.
The evolution of a process is directed by a pattern of rules
called a program. People create programs to direct processes. In effect,
we conjure the spirits of the computer with our spells."""

# %%
# for importing data from txt file
# with open("data.txt", "r", encoding="utf-8") as file:
#     data = file.read()

# %%
sentences = data.split(".")

# %%
sentences
# Out:
# ['We are about to study the idea of a computational process',
#  '\nComputational processes are abstract beings that inhabit computers',
#  '\nAs they evolve, processes manipulate other abstract things called data',
#  '\nThe evolution of a process is directed by a pattern of rules\ncalled a program',
#  ' People create programs to direct processes',
#  ' In effect,\nwe conjure the spirits of the computer with our spells',
#  '']

# %%
#Clean Data
clean_sentences = []
for sentence in sentences:
    # skip empty string
    if sentence == "":
        continue;
    # remove special characters
    sentence = re.sub('[^A-Za-z0-9]+', ' ', sentence)
    # remove 1 letter words
    sentence = re.sub(r'(?:^| )\w(?:$| )', ' ', sentence).strip()
    # lower all characters
    sentence = sentence.lower()
    clean_sentences.append(sentence)

# %%
clean_sentences
# Out:
# ['we are about to study the idea of computational process',
#  'computational processes are abstract beings that inhabit computers',
#  'as they evolve processes manipulate other abstract things called data',
#  'the evolution of process is directed by pattern of rules called program',
#  'people create programs to direct processes',
#  'in effect we conjure the spirits of the computer with our spells']

# %%
# Define the corpus
corpus = clean_sentences

# %%
# Convert the corpus to a sequence of integers
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
sequences = tokenizer.texts_to_sequences(corpus)
print("After converting our words in the corpus \
into vector of integers:")
print(sequences)
# Out:
# After converting our words in the corpus into vector of integers:
# [[4, 5, 11, 6, 12, 1, 13, 2, 7, 8], [7, 3, 5, 9, 14, 15, 16, 17], [18, 19, 20, 3, 21, 22, 9, 23, 10, 24], [1, 25, 2, 8, 26, 27, 28, 29, 2, 30, 10, 31], [32, 33, 34, 6, 35, 3], [36, 37, 4, 38, 1, 39, 2, 1, 40, 41, 42, 43]]

# %%
# creating dictionary for word to index and index to word
index_to_word_map = {}
word_to_index_map = {}
for index_1, sequence in enumerate(sequences):
    print(sequence)
    words_in_sentence = clean_sentences[index_1].split()
    print(words_in_sentence)
    for index_2, value in enumerate(sequence):
        index_to_word_map[value] = words_in_sentence[index_2]
        word_to_index_map[words_in_sentence[index_2]] = value
# Out:
# [4, 5, 11, 6, 12, 1, 13, 2, 7, 8]
# ['we', 'are', 'about', 'to', 'study', 'the', 'idea', 'of', 'computational', 'process']
# [7, 3, 5, 9, 14, 15, 16, 17]
# ['computational', 'processes', 'are', 'abstract', 'beings', 'that', 'inhabit', 'computers']
# [18, 19, 20, 3, 21, 22, 9, 23, 10, 24]
# ['as', 'they', 'evolve', 'processes', 'manipulate', 'other', 'abstract', 'things', 'called', 'data']
# [1, 25, 2, 8, 26, 27, 28, 29, 2, 30, 10, 31]
# ['the', 'evolution', 'of', 'process', 'is', 'directed', 'by', 'pattern', 'of', 'rules', 'called', 'program']
# [32, 33, 34, 6, 35, 3]
# ['people', 'create', 'programs', 'to', 'direct', 'processes']
# [36, 37, 4, 38, 1, 39, 2, 1, 40, 41, 42, 43]
# ['in', 'effect', 'we', 'conjure', 'the', 'spirits', 'of', 'the', 'computer', 'with', 'our', 'spells']

# %%
print(index_to_word_map)
print("\n")
print(word_to_index_map)
# Out:
# {4: 'we', 5: 'are', 11: 'about', 6: 'to', 12: 'study', 1: 'the', 13: 'idea', 2: 'of', 7: 'computational', 8: 'process', 3: 'processes', 9: 'abstract', 14: 'beings', 15: 'that', 16: 'inhabit', 17: 'computers', 18: 'as', 19: 'they', 20: 'evolve', 21: 'manipulate', 22: 'other', 23: 'things', 10: 'called', 24: 'data', 25: 'evolution', 26: 'is', 27: 'directed', 28: 'by', 29: 'pattern', 30: 'rules', 31: 'program', 32: 'people', 33: 'create', 34: 'programs', 35: 'direct', 36: 'in', 37: 'effect', 38: 'conjure', 39: 'spirits', 40: 'computer', 41: 'with', 42: 'our', 43: 'spells'}
#
#
# {'we': 4, 'are': 5, 'about': 11, 'to': 6, 'study': 12, 'the': 1, 'idea': 13, 'of': 2, 'computational': 7, 'process': 8, 'processes': 3, 'abstract': 9, 'beings': 14, 'that': 15, 'inhabit': 16, 'computers': 17, 'as': 18, 'they': 19, 'evolve': 20, 'manipulate': 21, 'other': 22, 'things': 23, 'called': 10, 'data': 24, 'evolution': 25, 'is': 26, 'directed': 27, 'by': 28, 'pattern': 29, 'rules': 30, 'program': 31, 'people': 32, 'create': 33, 'programs': 34, 'direct': 35, 'in': 36, 'effect': 37, 'conjure': 38, 'spirits': 39, 'computer': 40, 'with': 41, 'our': 42, 'spells': 43}

# %%
# Define the parameters
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 10
window_size = 2

# Generate the context-target pairs
contexts = []
targets = []
for sequence in sequences:
	for i in range(window_size, len(sequence) - window_size):
		context = sequence[i - window_size:i] + sequence[i + 1:i + window_size + 1]
		target = sequence[i]
		contexts.append(context)
		targets.append(target)

# %%
# sample of training data
for i in range(5):
    words = []
    target = index_to_word_map.get(targets[i])
    for j in contexts[i]:
        words.append(index_to_word_map.get(j))
    print(words, "=>", target)
# Out:
# ['we', 'are', 'to', 'study'] => about
# ['are', 'about', 'study', 'the'] => to
# ['about', 'to', 'the', 'idea'] => study
# ['to', 'study', 'idea', 'of'] => the
# ['study', 'the', 'of', 'computational'] => idea

# %%
# Convert the contexts and targets to numpy arrays
X = np.array(contexts)
Y = np.array(targets)

# %%
# Define the CBOW model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=2 * window_size))
model.add(Lambda(lambda x: tf.reduce_mean(x, axis=1)))
model.add(Dense(256, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(units=vocab_size, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, Y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 3s 29ms/step - loss: 3.7841 - accuracy: 0.0294
# Epoch 2/200
# 2/2 [==============================] - 0s 21ms/step - loss: 3.7755 - accuracy: 0.2059
# Epoch 3/200
# 2/2 [==============================] - 0s 18ms/step - loss: 3.7697 - accuracy: 0.2059
# Epoch 4/200
# 2/2 [==============================] - 0s 14ms/step - loss: 3.7634 - accuracy: 0.1471
# Epoch 5/200
# 2/2 [==============================] - 0s 16ms/step - loss: 3.7560 - accuracy: 0.2059
# Epoch 6/200
# 2/2 [==============================] - 0s 16ms/step - loss: 3.7471 - accuracy: 0.1765
# Epoch 7/200
# 2/2 [==============================] - 0s 16ms/step - loss: 3.7360 - accuracy: 0.1471
# Epoch 8/200
# 2/2 [==============================] - 0s 15ms/step - loss: 3.7239 - accuracy: 0.1176
# Epoch 9/200
# 2/2 [==============================] - 0s 16ms/step - loss: 3.7091 - accuracy: 0.1176
# Epoch 10/200
# 2/2 [==============================] - 0s 17ms/step - loss: 3.6918 - accuracy: 0.1176
# Epoch 11/200
# 2/2 [==============================] - 0s 17ms/step - loss: 3.6696 - accuracy: 0.1176
# Epoch 12/200
# 2/2 [==============================] - 0s 17ms/step - loss: 3.6444 - accuracy: 0.1176
# Epoch 13/200
# 2/2 [==============================] - 0s 17ms/step - loss: 3.6125 - accuracy: 0.1176
# Epoch 14/200
# 2/2 [==============================] - 0s 15ms/step - loss: 3.5747 - accuracy: 0.1176
# Epoch 15/200
# 2/2 [==============================] - 0s 16ms/step - loss: 3.5292 - accuracy: 0.1176
# Epoch 16/200
# 2/2 [==============================] - 0s 16ms/step - loss: 3.4766 - accuracy: 0.1176
# Epoch 17/200
# 2/2 [==============================] - 0s 13ms/step - loss: 3.4204 - accuracy: 0.1176
# Epoch 18/200
# 2/2 [==============================] - 0s 15ms/step - loss: 3.3591 - accuracy: 0.1176
# Epoch 19/200
# 2/2 [==============================] - 0s 13ms/step - loss: 3.3089 - accuracy: 0.1176
# Epoch 20/200
# 2/2 [==============================] - 0s 16ms/step - loss: 3.2631 - accuracy: 0.1176
# Epoch 21/200
# 2/2 [==============================] - 0s 17ms/step - loss: 3.2293 - accuracy: 0.1176
# Epoch 22/200
# 2/2 [==============================] - 0s 16ms/step - loss: 3.2125 - accuracy: 0.1176
# Epoch 23/200
# 2/2 [==============================] - 0s 14ms/step - loss: 3.1927 - accuracy: 0.1176
# Epoch 24/200
# 2/2 [==============================] - 0s 14ms/step - loss: 3.1781 - accuracy: 0.1176
# Epoch 25/200
# 2/2 [==============================] - 0s 15ms/step - loss: 3.1574 - accuracy: 0.1176
# Epoch 26/200
# 2/2 [==============================] - 0s 15ms/step - loss: 3.1233 - accuracy: 0.1176
# Epoch 27/200
# 2/2 [==============================] - 0s 14ms/step - loss: 3.0780 - accuracy: 0.1176
# Epoch 28/200
# 2/2 [==============================] - 0s 14ms/step - loss: 3.0363 - accuracy: 0.1471
# Epoch 29/200
# 2/2 [==============================] - 0s 17ms/step - loss: 3.0004 - accuracy: 0.1765
# Epoch 30/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.9713 - accuracy: 0.1765
# Epoch 31/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.9441 - accuracy: 0.1765
# Epoch 32/200
# 2/2 [==============================] - 0s 16ms/step - loss: 2.9239 - accuracy: 0.1471
# Epoch 33/200
# 2/2 [==============================] - 0s 17ms/step - loss: 2.8931 - accuracy: 0.1471
# Epoch 34/200
# 2/2 [==============================] - 0s 15ms/step - loss: 2.8608 - accuracy: 0.1471
# Epoch 35/200
# 2/2 [==============================] - 0s 16ms/step - loss: 2.8284 - accuracy: 0.2059
# Epoch 36/200
# 2/2 [==============================] - 0s 15ms/step - loss: 2.7984 - accuracy: 0.2059
# Epoch 37/200
# 2/2 [==============================] - 0s 37ms/step - loss: 2.7711 - accuracy: 0.1765
# Epoch 38/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.7434 - accuracy: 0.2059
# Epoch 39/200
# 2/2 [==============================] - 0s 16ms/step - loss: 2.7165 - accuracy: 0.2353
# Epoch 40/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.6857 - accuracy: 0.1765
# Epoch 41/200
# 2/2 [==============================] - 0s 15ms/step - loss: 2.6560 - accuracy: 0.1765
# Epoch 42/200
# 2/2 [==============================] - 0s 13ms/step - loss: 2.6262 - accuracy: 0.1765
# Epoch 43/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.5940 - accuracy: 0.1765
# Epoch 44/200
# 2/2 [==============================] - 0s 15ms/step - loss: 2.5563 - accuracy: 0.1765
# Epoch 45/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.5228 - accuracy: 0.1765
# Epoch 46/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.4937 - accuracy: 0.1765
# Epoch 47/200
# 2/2 [==============================] - 0s 19ms/step - loss: 2.4650 - accuracy: 0.1765
# Epoch 48/200
# 2/2 [==============================] - 0s 16ms/step - loss: 2.4401 - accuracy: 0.1765
# Epoch 49/200
# 2/2 [==============================] - 0s 13ms/step - loss: 2.4211 - accuracy: 0.1765
# Epoch 50/200
# 2/2 [==============================] - 0s 16ms/step - loss: 2.3984 - accuracy: 0.1765
# Epoch 51/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.3818 - accuracy: 0.1765
# Epoch 52/200
# 2/2 [==============================] - 0s 17ms/step - loss: 2.3598 - accuracy: 0.1765
# Epoch 53/200
# 2/2 [==============================] - 0s 15ms/step - loss: 2.3383 - accuracy: 0.1765
# Epoch 54/200
# 2/2 [==============================] - 0s 17ms/step - loss: 2.3218 - accuracy: 0.1765
# Epoch 55/200
# 2/2 [==============================] - 0s 15ms/step - loss: 2.3012 - accuracy: 0.2059
# Epoch 56/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.2776 - accuracy: 0.2647
# Epoch 57/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.2519 - accuracy: 0.2647
# Epoch 58/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.2245 - accuracy: 0.2647
# Epoch 59/200
# 2/2 [==============================] - 0s 13ms/step - loss: 2.1951 - accuracy: 0.3235
# Epoch 60/200
# 2/2 [==============================] - 0s 12ms/step - loss: 2.1585 - accuracy: 0.3235
# Epoch 61/200
# 2/2 [==============================] - 0s 18ms/step - loss: 2.1324 - accuracy: 0.3235
# Epoch 62/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.1040 - accuracy: 0.3529
# Epoch 63/200
# 2/2 [==============================] - 0s 16ms/step - loss: 2.0777 - accuracy: 0.3824
# Epoch 64/200
# 2/2 [==============================] - 0s 16ms/step - loss: 2.0492 - accuracy: 0.4706
# Epoch 65/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.0279 - accuracy: 0.4706
# Epoch 66/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.9952 - accuracy: 0.4706
# Epoch 67/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.9609 - accuracy: 0.4412
# Epoch 68/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.9315 - accuracy: 0.4412
# Epoch 69/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.9117 - accuracy: 0.3824
# Epoch 70/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.8886 - accuracy: 0.3824
# Epoch 71/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.8657 - accuracy: 0.4118
# Epoch 72/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8424 - accuracy: 0.3824
# Epoch 73/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.8144 - accuracy: 0.3529
# Epoch 74/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.7857 - accuracy: 0.3824
# Epoch 75/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.7627 - accuracy: 0.4706
# Epoch 76/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.7395 - accuracy: 0.5000
# Epoch 77/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.7155 - accuracy: 0.5000
# Epoch 78/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.6909 - accuracy: 0.5294
# Epoch 79/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.6631 - accuracy: 0.5294
# Epoch 80/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.6428 - accuracy: 0.5588
# Epoch 81/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.6109 - accuracy: 0.5588
# Epoch 82/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.5822 - accuracy: 0.5294
# Epoch 83/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.5477 - accuracy: 0.5588
# Epoch 84/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.5172 - accuracy: 0.5294
# Epoch 85/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.4904 - accuracy: 0.5000
# Epoch 86/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.4697 - accuracy: 0.5294
# Epoch 87/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.4415 - accuracy: 0.5000
# Epoch 88/200
# 2/2 [==============================] - 0s 19ms/step - loss: 1.4123 - accuracy: 0.5294
# Epoch 89/200
# 2/2 [==============================] - 0s 37ms/step - loss: 1.3878 - accuracy: 0.5294
# Epoch 90/200
# 2/2 [==============================] - 0s 17ms/step - loss: 1.3708 - accuracy: 0.5294
# Epoch 91/200
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3455 - accuracy: 0.5000
# Epoch 92/200
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3211 - accuracy: 0.5294
# Epoch 93/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.2918 - accuracy: 0.5294
# Epoch 94/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.2694 - accuracy: 0.5588
# Epoch 95/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.2422 - accuracy: 0.5882
# Epoch 96/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.2185 - accuracy: 0.5588
# Epoch 97/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1971 - accuracy: 0.5882
# Epoch 98/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1779 - accuracy: 0.6176
# Epoch 99/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1477 - accuracy: 0.6471
# Epoch 100/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.1285 - accuracy: 0.6765
# Epoch 101/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1039 - accuracy: 0.7059
# Epoch 102/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0961 - accuracy: 0.7353
# Epoch 103/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0801 - accuracy: 0.7059
# Epoch 104/200
# 2/2 [==============================] - 0s 18ms/step - loss: 1.0599 - accuracy: 0.7059
# Epoch 105/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0369 - accuracy: 0.6176
# Epoch 106/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0127 - accuracy: 0.6471
# Epoch 107/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.9895 - accuracy: 0.6765
# Epoch 108/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9648 - accuracy: 0.6471
# Epoch 109/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9443 - accuracy: 0.6765
# Epoch 110/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9177 - accuracy: 0.6765
# Epoch 111/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.8884 - accuracy: 0.7059
# Epoch 112/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8541 - accuracy: 0.7941
# Epoch 113/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.8253 - accuracy: 0.8529
# Epoch 114/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.8001 - accuracy: 0.8235
# Epoch 115/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.7753 - accuracy: 0.8529
# Epoch 116/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.7605 - accuracy: 0.8529
# Epoch 117/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.7447 - accuracy: 0.8235
# Epoch 118/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7265 - accuracy: 0.8529
# Epoch 119/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.7039 - accuracy: 0.8529
# Epoch 120/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6769 - accuracy: 0.8529
# Epoch 121/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6602 - accuracy: 0.8235
# Epoch 122/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6536 - accuracy: 0.8235
# Epoch 123/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6590 - accuracy: 0.8235
# Epoch 124/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6671 - accuracy: 0.7941
# Epoch 125/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6505 - accuracy: 0.8235
# Epoch 126/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.6164 - accuracy: 0.8529
# Epoch 127/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5822 - accuracy: 0.8529
# Epoch 128/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5480 - accuracy: 0.8235
# Epoch 129/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5192 - accuracy: 0.8529
# Epoch 130/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4972 - accuracy: 0.8824
# Epoch 131/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4825 - accuracy: 0.9118
# Epoch 132/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4735 - accuracy: 0.8824
# Epoch 133/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4638 - accuracy: 0.9118
# Epoch 134/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4560 - accuracy: 0.9118
# Epoch 135/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4506 - accuracy: 0.9118
# Epoch 136/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.4439 - accuracy: 0.8824
# Epoch 137/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4383 - accuracy: 0.8824
# Epoch 138/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4353 - accuracy: 0.8824
# Epoch 139/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4296 - accuracy: 0.8824
# Epoch 140/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4231 - accuracy: 0.8529
# Epoch 141/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4148 - accuracy: 0.8529
# Epoch 142/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4026 - accuracy: 0.8824
# Epoch 143/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3935 - accuracy: 0.8824
# Epoch 144/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3841 - accuracy: 0.8824
# Epoch 145/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3730 - accuracy: 0.8824
# Epoch 146/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3615 - accuracy: 0.8824
# Epoch 147/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3443 - accuracy: 0.8824
# Epoch 148/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3254 - accuracy: 0.9412
# Epoch 149/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3097 - accuracy: 0.9412
# Epoch 150/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2978 - accuracy: 0.9706
# Epoch 151/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2884 - accuracy: 0.9706
# Epoch 152/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2815 - accuracy: 0.9706
# Epoch 153/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2789 - accuracy: 0.9412
# Epoch 154/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2767 - accuracy: 0.9412
# Epoch 155/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2789 - accuracy: 0.9412
# Epoch 156/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2809 - accuracy: 0.9412
# Epoch 157/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2785 - accuracy: 0.9412
# Epoch 158/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2685 - accuracy: 0.9412
# Epoch 159/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2490 - accuracy: 0.9706
# Epoch 160/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2364 - accuracy: 0.9412
# Epoch 161/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2356 - accuracy: 0.9706
# Epoch 162/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2376 - accuracy: 0.9118
# Epoch 163/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2454 - accuracy: 0.9118
# Epoch 164/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2532 - accuracy: 0.9118
# Epoch 165/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2584 - accuracy: 0.9118
# Epoch 166/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2589 - accuracy: 0.9118
# Epoch 167/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2552 - accuracy: 0.9118
# Epoch 168/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2453 - accuracy: 0.9118
# Epoch 169/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2294 - accuracy: 0.9706
# Epoch 170/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2163 - accuracy: 0.9706
# Epoch 171/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2094 - accuracy: 0.9706
# Epoch 172/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1950 - accuracy: 0.9706
# Epoch 173/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1812 - accuracy: 0.9706
# Epoch 174/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1687 - accuracy: 0.9706
# Epoch 175/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1618 - accuracy: 0.9706
# Epoch 176/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1578 - accuracy: 0.9706
# Epoch 177/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1561 - accuracy: 1.0000
# Epoch 178/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1559 - accuracy: 1.0000
# Epoch 179/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1542 - accuracy: 1.0000
# Epoch 180/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1526 - accuracy: 1.0000
# Epoch 181/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1495 - accuracy: 1.0000
# Epoch 182/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1444 - accuracy: 1.0000
# Epoch 183/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1356 - accuracy: 1.0000
# Epoch 184/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1247 - accuracy: 1.0000
# Epoch 185/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1198 - accuracy: 1.0000
# Epoch 186/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1209 - accuracy: 1.0000
# Epoch 187/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1266 - accuracy: 0.9706
# Epoch 188/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1289 - accuracy: 0.9706
# Epoch 189/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1277 - accuracy: 0.9706
# Epoch 190/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1256 - accuracy: 0.9706
# Epoch 191/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1230 - accuracy: 0.9706
# Epoch 192/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1193 - accuracy: 0.9706
# Epoch 193/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1121 - accuracy: 0.9706
# Epoch 194/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1018 - accuracy: 1.0000
# Epoch 195/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0957 - accuracy: 1.0000
# Epoch 196/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0955 - accuracy: 1.0000
# Epoch 197/200
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1007 - accuracy: 0.9706
# Epoch 198/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1059 - accuracy: 0.9706
# Epoch 199/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1125 - accuracy: 0.9706
# Epoch 200/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1185 - accuracy: 0.9706

# %%
# Get the word embeddings
embeddings = model.get_weights()[0]

# Perform PCA to reduce the dimensionality of the embeddings
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(embeddings)

# %%
# Visualize the embeddings
plt.figure(figsize=(7, 7))
for i, word in enumerate(tokenizer.word_index.keys()):
    x, y = reduced_embeddings[i]
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2),
                 textcoords='offset points',
                 ha='right', va='bottom')
plt.show()

# %%
# test model
test_sentenses = [
    "we are to study",
    "create programs direct processes",
    "spirits process study program",
    "idea study people create"
]

# %%
for test_sentense in test_sentenses:
    test_words = test_sentense.split(" ")
    print("Words: ", test_words)
    x_test = []
    for i in test_words:
        x_test.append(word_to_index_map.get(i))
    x_test = np.array([x_test])
    print("Indexs: ", x_test)
    test_predictions = model.predict(x_test)
    y_pred = np.argmax(test_predictions[0])
    print("Predictons: ",test_words, " => ", index_to_word_map.get(y_pred))
    print("\n")
# Out:
# Words:  ['we', 'are', 'to', 'study']
# Indexs:  [[ 4  5  6 12]]
# 1/1 [==============================] - 0s 329ms/step
# Predictons:  ['we', 'are', 'to', 'study']  =>  about
#
#
# Words:  ['create', 'programs', 'direct', 'processes']
# Indexs:  [[33 34 35  3]]
# 1/1 [==============================] - 0s 69ms/step
# Predictons:  ['create', 'programs', 'direct', 'processes']  =>  to
#
#
# Words:  ['spirits', 'process', 'study', 'program']
# Indexs:  [[39  8 12 31]]
# 1/1 [==============================] - 0s 69ms/step
# Predictons:  ['spirits', 'process', 'study', 'program']  =>  about
#
#
# Words:  ['idea', 'study', 'people', 'create']
# Indexs:  [[13 12 32 33]]
# 1/1 [==============================] - 0s 65ms/step
# Predictons:  ['idea', 'study', 'people', 'create']  =>  programs

# %%
# Build the Image classification model by dividing the model into following 4 stages:
# a. Loading and preprocessing the image data
# b. Defining the model’s architecture
# c. Training the model
# d. Estimating the model’s performance

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()

# %%
x_train=x_train/255
x_test=x_test/255

# %%
model=keras.Sequential([
    keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(),metrics=['accuracy'])

# %%
model.fit(x_train,y_train,batch_size=30,epochs=5,validation_data=(x_test,y_test),shuffle=True)
# Out:
# Epoch 1/5
# 2000/2000 [==============================] - 44s 21ms/step - loss: 0.1555 - accuracy: 0.9541 - val_loss: 0.0674 - val_accuracy: 0.9778
# Epoch 2/5
# 2000/2000 [==============================] - 42s 21ms/step - loss: 0.0547 - accuracy: 0.9829 - val_loss: 0.0546 - val_accuracy: 0.9809
# Epoch 3/5
# 2000/2000 [==============================] - 42s 21ms/step - loss: 0.0365 - accuracy: 0.9886 - val_loss: 0.0434 - val_accuracy: 0.9854
# Epoch 4/5
# 2000/2000 [==============================] - 42s 21ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.0421 - val_accuracy: 0.9865
# Epoch 5/5
# 2000/2000 [==============================] - 41s 21ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0544 - val_accuracy: 0.9847

# %%
loss,accuracy=model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0544 - accuracy: 0.9847

# %%
print(loss*100)
print(accuracy*100)
# Out:
# 5.443662777543068
# 98.47000241279602

# %%
def graph(image,digit,plt,i):
    plt.subplot(4,6,i+1)
    plt.imshow(image)
    plt.xticks([])
    plt.yticks([])

# %%
for i in range(20):
    graph(x_train[i],y_train[i],plt,i)

# %%
pred=model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step

# %%
plt.imshow(x_test[10])

# %%
print(f"The handwritten value predicted is : {np.argmax(pred[10])}")
print(f"The actual value  is : {np.argmax(y_test[10])}")
# Out:
# The handwritten value predicted is : 0
# The actual value  is : 0
